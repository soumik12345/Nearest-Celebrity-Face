# %%
from glob import glob
from PIL import Image

# %%
results = glob('./Results/*')

# %%
Image.open(results[0])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x500 at 0x1103BFA10>

# %%
Image.open(results[1])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x500 at 0x110EBA9D0>

# %%
Image.open(results[2])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x500 at 0x110EBAF50>

# %%
Image.open(results[3])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x500 at 0x110EBE4D0>

# %%
Image.open(results[4])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1280x500 at 0x110EBE750>

# %%
Image.open(results[5])
